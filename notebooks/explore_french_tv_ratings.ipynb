# %% [markdown]
# # Explore

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## import packages

# %%
import sys
sys.path.append('..')

# %%
from source.data.mediasportif import get_matchs_data_from_url

# %% [markdown]
# ## Scrap french ratings 2018 - 2022

# %%
url = "https://www.mediasportif.fr/2018/06/15/coupe-du-monde-2018-toutes-les-audiences-de-la-competition-en-france/"
game_ratings_2018_df = get_matchs_data_from_url(url)

# %%
url = "https://www.mediasportif.fr/2022/11/21/30655/"
game_ratings_2022_df = get_matchs_data_from_url(url)

# %% [markdown]
# ## All games

# %%
game_ratings_2018_df
# Out:
#           date day_of_week day    month  year            game_type hour  \
# 0   2018-06-14       JEUDI  14     JUIN  2018                POULE  17h
# 1   2018-06-15    VENDREDI  15     JUIN  2018                POULE  20h
# 2   2018-06-16      SAMEDI  16     JUIN  2018                POULE  12h
# 3   2018-06-16      SAMEDI  16     JUIN  2018                POULE  21h
# 4   2018-06-17    DIMANCHE  17     JUIN  2018                POULE  17h
# 5   2018-06-17    DIMANCHE  17     JUIN  2018                POULE  20h
# 6   2018-06-18       LUNDI  18     JUIN  2018                POULE  20h
# 7   2018-06-20    MERCREDI  20     JUIN  2018                POULE  20h
# 8   2018-06-21       JEUDI  21     JUIN  2018                POULE  17h
# 9   2018-06-21       JEUDI  21     JUIN  2018                POULE  20h
# 10  2018-06-23      SAMEDI  23     JUIN  2018                POULE  20h
# 11  2018-06-24    DIMANCHE  24     JUIN  2018                POULE  20h
# ...

# %%
game_ratings_2022_df
# Out:
#           date day_of_week  day     month  year            game_type hour  \
# 0   2022-11-20    DIMANCHE   20  NOVEMBRE  2022                POULE  17h
# 1   2022-11-21       LUNDI   21  NOVEMBRE  2022                POULE  20h
# 2   2022-11-22       MARDI   22  NOVEMBRE  2022                POULE  20h
# 3   2022-11-23    MERCREDI   23  NOVEMBRE  2022                POULE  20h
# 4   2022-11-24       JEUDI   24  NOVEMBRE  2022                POULE  20h
# 5   2022-11-25    VENDREDI   25  NOVEMBRE  2022                POULE  20h
# 6   2022-11-26      SAMEDI   26  NOVEMBRE  2022                POULE  17h
# 7   2022-11-26      SAMEDI   26  NOVEMBRE  2022                POULE  20h
# 8   2022-11-27    DIMANCHE   27  NOVEMBRE  2022                POULE  14h
# 9   2022-11-27    DIMANCHE   27  NOVEMBRE  2022                POULE  20h
# 10  2022-11-28       LUNDI   28  NOVEMBRE  2022                POULE  20h
# 11  2022-11-29       MARDI   29  NOVEMBRE  2022                POULE  20h
# ...

# %% [markdown]
# ## France games

# %%
game_ratings_2018_df.loc[
    (game_ratings_2018_df.team_1 == "France")
    | (game_ratings_2018_df.team_2 == "France")
]
# Out:
#           date day_of_week day    month  year            game_type hour  \
# 2   2018-06-16      SAMEDI  16     JUIN  2018                POULE  12h
# 8   2018-06-21       JEUDI  21     JUIN  2018                POULE  17h
# 13  2018-06-26       MARDI  26     JUIN  2018                POULE  16h
# 17  2018-06-30      SAMEDI  30     JUIN  2018  HUITIÈMES DE FINALE  16h
# 23  2018-07-06    VENDREDI  06  JUILLET  2018     QUARTS DE FINALE  16h
# 26  2018-07-10       MARDI  10  JUILLET  2018          DEMI-FINALE  20h
# 29  2018-07-15    DIMANCHE  15  JUILLET  2018               FINALE  17h
#
#       team_1     team_2   ratings
# 2     France  Australie  12590000
# 8     France      Pérou  10720000
# 13  Danemark     France   8670000
# 17    France  Argentine  13595000
# 23   Uruguay     France  12880000
# 26    France   Belgique  20178000
# 29    France    Croatie  19340000

# %%
game_ratings_2022_df.loc[
    (game_ratings_2022_df.team_1 == "FRANCE")
    | (game_ratings_2022_df.team_2 == "FRANCE")
]
# Out:
#           date day_of_week day     month  year            game_type hour  \
# 2   2022-11-22       MARDI  22  NOVEMBRE  2022                POULE  20h
# 6   2022-11-26      SAMEDI  26  NOVEMBRE  2022                POULE  17h
# 12  2022-11-30    MERCREDI  30  NOVEMBRE  2022                POULE  16h
# 17  2022-12-04    DIMANCHE  04  DECEMBRE  2022  HUITIÈMES DE FINALE  16h
#
#      team_1     team_2   ratings
# 2    FRANCE  Australie  13109000
# 6    FRANCE   Danemark  11590000
# 12  Tunisie     FRANCE   8838000
# 17   FRANCE    Pologne  14324000
